# %%
import requests

lastname="Anand"
top = 30

print('Downloading ZIP with PGNs of '+lastname)
zipFileUrl = "https://www.pgnmentor.com/players/"+lastname+".zip"
r = requests.get(zipFileUrl)
path_to_zip_file = '/Users/inotin/Downloads/'+lastname+'.zip'
print("Download successful")
with open(path_to_zip_file, 'wb') as f:  
    f.write(r.content)
# Out:
# Downloading ZIP with PGNs of Anand
# Download successful

# %%
import zipfile
directory_to_extract_to = '/Users/inotin/Downloads/'+lastname

zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
zip_ref.extractall(directory_to_extract_to)
zip_ref.close()

# %%
with open(directory_to_extract_to+'/'+lastname+'.pgn', 'r') as file:
    data_from_pgn = file.read().replace('\n', '')
    
ds = data_from_pgn.split(sep="ECO")
deb_code = []
for d in ds:
    deb_code.append(d[2:5])
deb_data ={}
deb_num = []
for deb in deb_code:
    deb_data[deb]=deb_code.count(deb)
    deb_num.append(deb_code.count(deb))

# %%
import operator
sorted_x = sorted(deb_data.items(), key=operator.itemgetter(1))

# %%
import matplotlib.pyplot as plt
for data_dict in sorted_x[len(sorted_x)-top:]:
    x = data_dict[0]
    y = data_dict[1]
    plt.scatter(x, y)

# %%
dr = requests.get("http://www.neerpeltersk.be/palview4/p4sets/P3eco.txt")
path_to_Eco = '/Users/inotin/Downloads/eco2.txt'

with open(path_to_Eco, 'wb') as f:  
    f.write(dr.content)

# %%
with open(path_to_Eco, 'r') as file:
    data_from_eco = file.read()

# %%
import re
eco_list = re.findall(r'\n[A,B,C,D,E][^\n]+',data_from_eco)

# %%
i = top
for s in sorted_x[len(sorted_x)-top:]:
    variants=""
    for e in eco_list:
        if s[0]==e[1:4]:
            if variants !="":
                variants = variants + "\nOR" + e[4:].split(sep=";")[0]
            else:
                variants = e[4:].split(sep=";")[0]
    print("==============================")        
    print("Number", i, "in Top", top, "is", s[0],":", variants, "\n")
    i-=1
# Out:
# ==============================
# Number 30 in Top 30 is D45 :     QGD: Semi-Slav: 5.e3
# OR    QGD: Semi-Slav: Accelerated Meran
# OR    QGD: Semi-Slav: 5...Nd7
# OR    QGD: Semi-Slav: Rubinstein (Anti-Meran) System
# OR    QGD: Semi-Slav: Stoltz Variation
# OR    QGD: Semi-Slav: Stonewall Defense
#
# ==============================
# Number 29 in Top 30 is B48 :     Sicilian: Taimanov Variation
#
# ==============================
# Number 28 in Top 30 is B30 :     Sicilian Defense
# OR    Sicilian Defense
# OR    Sicilian Defense
# OR    Sicilian: Nimzovich-Rossolimo Attack
# OR/15 Sicilian: Nimzovich-Rossolimo Attack: 4.Bxc6 5.d3 Hennigan
# OR/11 Sicilian: Nimzovich-Rossolimo Attack: 5.b3
# OR/12 Sicilian: Nimzovich-Rossolimo Attack: 5.c3
# OR    Sicilian: Nimzovich-Rossolimo Attack: Zagrebelny Variation
# OR/10 Sicilian: Nimzovich-Rossolimo Attack: 5.Re1
# OR    Sicilian Defense
# OR    Sicilian Defense
# OR    Sicilian Defense
#
# ==============================
# Number 27 in Top 30 is B85 :     Sicilian: Scheveningen: Classical Main Line
# OR/05 Sicilian: Scheveningen: Classical Main Line
# OR/01 Sicilian: Scheveningen: Classical
# OR/04 Sicilian: Scheveningen: Classical
# OR    Sicilian: Scheveningen: Classical (with...Qc7 &...Nc6)
# OR    Sicilian: Scheveningen: Classical
# OR    Sicilian: Scheveningen: Classical Main Line
# OR/01 Sicilian: Scheveningen: Modern Line
# OR/01 Sicilian: Scheveningen: Modern Line
# OR/35 Sicilian: Scheveningen: Classical
# OR/15 Sicilian: Scheveningen: Modern Main Line (...Bd7 Qe1)
# OR/23 Sicilian: Scheveningen: Classical (...b6)
# OR/35 Sicilian: Scheveningen: Classical (Ndb5)
# OR/19 Sicilian: Scheveningen: Modern Main Line
# OR/14 Sicilian: Scheveningen: Modern Main Line (...Qb8)
# OR    Sicilian: Scheveningen: Classical Main Line
# OR/36 Sicilian: Scheveningen: Classical Main Line
# OR    Sicilian: Scheveningen: Classical
#
# ==============================
# Number 26 in Top 30 is B92 :     Sicilian: Najdorf: Opovcensky Variation
# OR/21 Sicilian: Najdorf: Opovcensky, Main Line
#
# ==============================
# Number 25 in Top 30 is D27 :     QGA: Classical: 6...a6
# OR    QGA: Classical: Rubinstein Variation
# OR/17 QGA: Classical: Rubinstein Variation, Main Line
# OR    QGA: Classical: Geller Variation
# OR/22 QGA: Classical: 7.Bb3
# OR    QGA: Classical (with Nc3)
#
# ==============================
# Number 24 in Top 30 is B17 :     Caro-Kann: Smyslov Variation
# OR/09 Caro-Kann: Smyslov Variation: 6.Bd3
# OR/13 Caro-Kann: Smyslov Variation: 8.Bd3
#
# ==============================
# Number 23 in Top 30 is C92 :     Ruy Lopez: Closed: 9.h3
# OR    Ruy Lopez: Closed: Keres 9...a5 Variation
# OR    Ruy Lopez: Closed: Flohr-Zaitsev System
# OR/26 Ruy Lopez: Closed: Flohr-Zaitsev System
# OR    Ruy Lopez: Closed: Kholmov Variation
# OR    Ruy Lopez: Closed: Ragozin-Petrosian (Keres)
#
# ==============================
# Number 22 in Top 30 is B31 :     Sicilian: Nimzovich-Rossolimo Attack
# OR/03 Sicilian: Nimzovich-Rossolimo Attack: 4.Bxc6
# OR    Sicilian: Nimzovich-Rossolimo Attack: Gurgenidze Variation
# OR/12 Sicilian: Nimzovich-Rossolimo Attack: Modern Line
#
# ==============================
# Number 21 in Top 30 is C84 :     Ruy Lopez: Closed Centre (5...b5)
# OR    Ruy Lopez: Closed Defense
# OR/01 Ruy Lopez: Closed Centre (6.d3)
# OR/05 Ruy Lopez: Closed Centre (7...d6)
# OR/02 Ruy Lopez: Closed Centre (7...Bb7)
# OR    Ruy Lopez: Closed: Centre Attack
# OR    Ruy Lopez: Closed: Basque Gambit
#
# ==============================
# Number 20 in Top 30 is B19 :     Caro-Kann: Classical: 7...Nd7
# OR    Caro-Kann: Classical: Spassky Variation
# OR/10 Caro-Kann: Classical: Spassky Variation
#
# ==============================
# Number 19 in Top 30 is A07 :     Reti: King's Indian Attack (Barcza System)
# OR    Reti: King's Indian Attack (with...c5)
# OR/14 Reti: King's Indian Attack: Yugoslav Variation
# OR    Reti: King's Indian Attack: Pachman System
# OR    Reti: King's Indian Attack: Keres Variation
# OR    Reti: King's Indian Attack
# OR    Reti: King's Indian Attack: Herringbone Variation
# OR    Reti: King's Indian Attack: Yugoslav Variation
# OR/05 Reti: King's Indian Attack (...Bf5)
# OR/07 Reti: KIA, Neo-Gruenfeld
# OR/04 Reti: King's Indian Attack: Yugoslav Variation
# OR    Reti: King's Indian Attack: Yugoslav Variation
# OR    Reti: King's Indian Attack: Petrosian Variation
# OR    Reti: King's Indian Attack (with...c5)
# OR    Reti: King's Indian Attack: Yugoslav Variation (d3)
# OR    Reti: King's Indian Attack (...e5)
# OR Reti: King's Indian Attack
#
# ==============================
# Number 18 in Top 30 is B80 :     Sicilian: Scheveningen Variation
# OR    Sicilian: Scheveningen: English Variation
# OR/09 Sicilian: Scheveningen: Variation (f3)
# OR/03 Sicilian: Scheveningen: Fianchetto Variation
# OR    Sicilian: Scheveningen: Fianchetto (Modern Line)
# OR Sicilian: Scheveningen: Vitolins Variation
#
# ==============================
# Number 17 in Top 30 is C53 :     Giuoco Piano
# OR    Giuoco Piano
# OR    Giuoco Piano: Bird's Attack
# OR    Giuoco Piano
# OR    Giuoco Piano: Anderssen Variation
# OR    Giuoco Piano: Close Variation
# OR    Giuoco Piano: Eisinger Variation
# OR Giuoco Piano: LaBourdonnais Variation
# OR Giuoco Piano
# OR Giuoco Piano: Ghulam Kassim Variation
# OR Giuoco Piano: Centre-holding Variation
# OR Giuoco Piano: Mestel Variation
# OR Giuoco Piano: Tarrasch Variation
#
# ==============================
# Number 16 in Top 30 is C10 :     French: Paulsen Variation
# OR    French: Marshall Variation
# OR    French: Fort Knox Variation
# OR    French: Rubinstein Variation
# OR    French: Rubinstein: Capablanca Line
# OR French: Rubinstein Variation
# OR French: Frere (Becker) Variation
#
# ==============================
# Number 15 in Top 30 is C89 :     Ruy Lopez: Marshall Counter-Attack
# OR    Ruy Lopez: Marshall: Herman Steiner Variation
# OR    Ruy Lopez: Marshall Counter-Attack
# OR    Ruy Lopez: Marshall: Main Line
# OR    Ruy Lopez: Marshall: Main Line, Spassky
# OR    Ruy Lopez: Marshall: Kevitz Variation
# OR Ruy Lopez: Marshall: Main Line 12.d4
#
# ==============================
# Number 14 in Top 30 is D43 :     QGD: Semi-Slav
# OR    QGD: Semi-Slav
# OR    QGD: Semi-Slav: Hastings Variation
#
# ==============================
# Number 13 in Top 30 is E12 :     Queen's Indian Defense
# OR    Queen's Indian: Petrosian System
# OR/76 Queen's Indian: Petrosian System: Main Line
# OR/57 Queen's Indian: Petrosian System: Alternate Main Line
# OR    Queen's Indian: Miles Variation
# OR    Queen's Indian: 4.Nc3
# OR    Queen's Indian: 4.Nc3: Botvinnik Variation
#
# ==============================
# Number 12 in Top 30 is C11 :     French Defense
# OR    French: Steinitz Variation
# OR    French: Steinitz Variation
# OR    French: Steinitz: Boleslavsky Variation
# OR    French: Steinitz: Gledhill Attack
# OR    French: Swiss Variation
# OR    French: Burn Variation
# OR/19 French: Burn Variation: Main Line
# OR/15 French: Modern Burn Variation (Balasov)
# OR French: Henneberger Variation
# OR French: Steinitz: Bradford Attack
# OR French: Steinitz: Brodsky-Jones Variation
#
# ==============================
# Number 11 in Top 30 is C78 :     Ruy Lopez: (...b5...d6)
# OR    Ruy Lopez: Archangelsk (counterthrust) Variation
# OR    Ruy Lopez: Archangel Variation (...Bc5)
# OR/17 Ruy Lopez: Archangel Variation (...Bc5)
# OR    Ruy Lopez: Wing Attack
# OR    Ruy Lopez: Moeller Defense
# OR Ruy Lopez: 5.O-O
# OR Ruy Lopez: Rabinovich Variation
#
# ==============================
# Number 10 in Top 30 is B12 :     Caro-Kann Defense
# OR    Caro-Kann Defense
# OR/02 Caro-Kann: 3.e5 c5
# OR/02 Caro-Kann: 3.e5 c5
# OR    Caro-Kann: Advance Variation
# OR/13 Caro-Kann: Advance Variation
# OR/19 Caro-Kann: Advance: (Karpov, Seirawan)
# OR/16 Caro-Kann: Advance: Main Line
# OR    Caro-Kann: Tartakower Variation
# OR    Caro-Kann: 3.Nd2
# OR    Caro-Masi Defense
# OR/23 Caro-Kann-Robatsch
# OR Caro-Kann: Edinburgh Variation
# OR de Bruycker Defense
#
# ==============================
# Number 9 in Top 30 is D37 :     QGD: 4.Nf3
# OR/22 QGD: 5.Bf4
#
# ==============================
# Number 8 in Top 30 is B33 :     Sicilian Defense
# OR    Sicilian: Pelikan Variation: (Lasker-Sveshnikov)
# OR/09 Sicilian: Sveshnikov Variation: a4
# OR    Sicilian: Pelikan: Chelyabinsk Variation
# OR    Sicilian: Sveshnikov Variation
# OR/42 Sicilian: Sveshnikov Variation
# OR/43 Sicilian: Sveshnikov: 9.Bxf6
# OR/43 Sicilian: Sveshnikov: 5...e6
# OR/30 Sicilian: Sveshnikov: Novosibirsk Variation (Kramnik)
# OR/32 Sicilian: Sveshnikov: Novosibirsk Variation 11.Bd3
# OR/27 Sicilian: Sveshnikov: 9.Nd5
# OR    Sicilian: Pelikan: Bird Variation
# OR/04 Sicilian: Neo-Pelikan: (...Qb6 Nb3)
#
# ==============================
# Number 7 in Top 30 is C88 :     Ruy Lopez: Closed: Balla Variation
# OR    Ruy Lopez: Closed: 7...h6 8.d4
# OR    Ruy Lopez: Trajkovic Counter-Attack
# OR    Ruy Lopez: Closed: 7...O-O
# OR    Ruy Lopez: Closed: Anti-Marshall 8.a4
# OR    Ruy Lopez: Closed: 8.c3
# OR Ruy Lopez: Closed
# OR Ruy Lopez: Closed: Leonhardt Variation
# OR Ruy Lopez: Noah's Ark Trap
#
# ==============================
# Number 6 in Top 30 is C50 :     King's Pawn Game
# OR    Rousseau Gambit
# OR    Giuoco Piano
# OR    Giuoco Pianissimo
# OR    Giuoco Pianissimo
# OR    Giuoco Pianissimo: Italian Four Knights Variation
# OR    Giuoco Pianissimo: Canal Variation
# OR/06 Giuoco Piano: Four Knights Variation
# OR    Hungarian Defense
# OR    Hungarian Defense: Tartakower Variation
# OR Blackburne shilling Gambit
# OR Giuoco Piano: Jerome Gambit
# OR Giuoco Pianissimo: Dubois Variation
#
# ==============================
# Number 5 in Top 30 is E15 :     Queen's Indian: 4.g3
# OR    Queen's Indian: Nimzovich Variation: (Exaggerated Fianchetto)
# OR/40 Queen's Indian: Nimzovich Variation: (Exaggerated Fianchetto), Main Line
# OR    Queen's Indian: Rubinstein Variation
# OR Queen's Indian: 4.g3 Bb7
# OR Queen's Indian: Buerger Variation
#
# ==============================
# Number 4 in Top 30 is C67 :     Ruy Lopez: Berlin Defense: Open Variation
# OR/04 Ruy Lopez: Berlin Defense: Rosenthal Variation
# OR    Ruy Lopez: Open Berlin Defense: 5...Be7
# OR    Ruy Lopez: Berlin Defense: Minckwitz Variation
# OR    Ruy Lopez: Berlin Defense: Pillsbury Variation
# OR    Ruy Lopez: Berlin Defense: Rio de Janeiro Variation
# OR    Ruy Lopez: Berlin Defense: Winawer Attack
# OR    Ruy Lopez: Open Berlin Defense: l'Hermet Variation
# OR/08 Ruy Lopez: Open Berlin Defense: 6.Bxc6
# OR Ruy Lopez: Berlin Defense: Trifunovic Variation
# OR Ruy Lopez: Berlin Defense: Zukertort Variation
# OR Ruy Lopez: Berlin Defense: Cordel Variation
# OR Ruy Lopez: Open Berlin Defense: Showalter Variation
#
# ==============================
# Number 3 in Top 30 is C65 :     Ruy Lopez: Berlin Defense
# OR/01 Ruy Lopez: Berlin Defense: Steinitz Variation
# OR    Ruy Lopez: Berlin Defense: Duras Variation
# OR    Ruy Lopez: Berlin Defense: Anderssen Variation
# OR    Ruy Lopez: Berlin Defense: Kaufmann Variation
# OR    Ruy Lopez: Berlin Defense: Mortimer Variation
# OR    Ruy Lopez: Berlin Defense: Nyholm Attack
# OR    Ruy Lopez: Berlin Defense: 4.O-O
# OR    Ruy Lopez: Berlin Defense: Beverwijk Variation
# OR    Ruy Lopez: Classical Defense: Benelux Variation
# OR Ruy Lopez: Berlin Defense: Mortimer Trap
#
# ==============================
# Number 2 in Top 30 is C42 :     Petrov's Defense
# OR/01 Russian Defense: (Petroff's)
# OR    Petrov: Three Knights Game
# OR    Petrov: Paulsen Attack
# OR    Petrov: Kaufmann Attack
# OR    Petrov: French Attack
# OR    Petrov: Classical Attack: Marshall Variation
# OR    Petrov: Classical Attack: Tarrasch Variation
# OR    Petrov: Classical Attack: Marshall Trap
# OR    Petrov: Classical Attack: Jaenisch Variation
# OR    Petrov: Classical Attack: Chigorin Variation
# OR    Petrov: Classical Attack: Berger Variation
# OR    Petrov: Classical Attack: Mason Variation
# OR/20 Petrov: Classical Attack: Jaenisch Variation (Kramnik)
# OR    Petrov: Nimzovich Attack
# OR    Petrov: Cozio (Lasker) Attack
# OR    Petrov: Cochrane Gambit
# OR    Petrov: Damiano Variation
# OR/04 Petrov: Damiano Variation: 4.Qe2
# OR Petrov: Italian Variation
# OR Petrov: Classical Attack
# OR Petrov: Classical Attack: Krause Variation
# OR Petrov: Classical Attack: Maroczy Variation
# OR Petrov: Classical Attack: Close Variation
# OR/01 Russian Defense: (Petroff's) Lichtehein Variation
#
# ==============================
# Number 1 in Top 30 is B90 :     Sicilian: Najdorf
# OR/10 Sicilian: Najdorf: Byrne-Sax Attack
# OR    Sicilian: Najdorf: Adams Attack
# OR    Sicilian: Najdorf: Lipnitzky Attack
# OR    Sicilian: Najdorf: Byrne (English) Attack
# OR/04 Sicilian: Najdorf: Byrne-Almasi Attack
# OR/06 Sicilian: Najdorf: Byrne Attack (...Ng4)
